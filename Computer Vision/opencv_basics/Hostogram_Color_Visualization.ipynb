# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("F:\\Master OpenCV\\images\\input.jpg")

# %%
histogram = cv2.calcHist(image,[0],None,[256],[0,256])
plt.hist(image.ravel(),256,[0,256])
# Out:
# (array([  8706.,   3448.,   5218.,   8084.,  11788.,  12957.,  14583.,
#          15348.,  16068.,  17849.,  19760.,  26710.,  34149.,  39245.,
#          52333.,  74282.,  92507., 110062.,  81826.,  79237.,  92290.,
#         110815., 122724., 120383., 117992.,  89921.,  69199.,  69387.,
#          81019.,  88048.,  82761.,  70285.,  58345.,  41683.,  31262.,
#          27924.,  27514.,  29125.,  26620.,  29238.,  34431.,  49008.,
#          57804.,  55692.,  37633.,  35046.,  36529.,  41747.,  43143.,
#          40863.,  34166.,  33692.,  34613.,  33743.,  35259.,  30136.,
#          26966.,  25661.,  24575.,  22447.,  17779.,  13527.,   9880.,
#           7312.,   5737.,   4884.,   4483.,   4311.,   4108.,   4052.,
#           4052.,   3875.,   3864.,   3608.,   3691.,   3543.,   3597.,
#           3548.,   3394.,   3225.,   3219.,   3138.,   2976.,   2898.,
#           2856.,   2767.,   2609.,   2648.,   2543.,   2468.,   2415.,
# ...

# %%
color = ('b', 'g','r')

for i,color in enumerate(color):
    hist = cv2.calcHist(image,[i],None,[256],[0,256])
    plt.plot(hist,color = color)
    plt.xlim([0,256])
    plt.show()
plt.show()

# %%
image1 = cv2.imread("F:\\Master OpenCV\\images\\tobago.jpg")

# %%
hist = cv2.calcHist(image1,[0],None,[256],[0,256])
plt.hist(image1.ravel(),256,[0,256])
# Out:
# (array([185089.,  44097.,  42412.,  41641.,  42791.,  47232.,  52455.,
#          57528.,  60581.,  64056.,  66243.,  68751.,  69597.,  70808.,
#          71797.,  73204.,  75854.,  79683.,  83075.,  86360.,  89910.,
#          92844.,  95220.,  94991.,  93327.,  91664.,  89847.,  86771.,
#          83419.,  78046.,  73778.,  69618.,  65928.,  62693.,  59040.,
#          56273.,  52797.,  50071.,  47421.,  45724.,  44037.,  42661.,
#          41573.,  40516.,  40045.,  39914.,  38876.,  38255.,  37476.,
#          37216.,  36059.,  35743.,  34595.,  33785.,  33473.,  32766.,
#          31694.,  30835.,  30101.,  29534.,  28894.,  28264.,  27907.,
#          27105.,  26726.,  26357.,  26450.,  25929.,  25328.,  24880.,
#          23824.,  23900.,  23348.,  23328.,  23323.,  22857.,  22443.,
#          22184.,  22116.,  21720.,  21400.,  21056.,  20485.,  20348.,
#          20297.,  20019.,  19491.,  19558.,  19412.,  19081.,  19080.,
# ...

# %%
color = ('b', 'g','r')

for i,color in enumerate(color):
    hist = cv2.calcHist([image1],[i],None,[256],[0,256])
    plt.plot(hist,color = color)
    plt.xlim([0,256])
    plt.show()
plt.show()
