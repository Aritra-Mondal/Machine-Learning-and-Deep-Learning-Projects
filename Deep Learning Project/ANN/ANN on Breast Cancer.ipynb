# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("F:\\Datasets\\cancer_classification.csv")

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# benign_0__mal_1            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1',data=df)

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())

# %%
X = df.drop('benign_0__mal_1',axis=1)
y = df['benign_0__mal_1']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train.shape
# Out:
# (398, 30)

# %%
model = Sequential()
model.add(Dense(30,activation='relu'))

model.add(Dense(15,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer = "adam", loss = 'binary_crossentropy')

# %%
model.fit(x=X_train, y=y_train.values,validation_data=(X_test,y_test.values),epochs=600)
# Out:
# /600
# 398/398 [==============================] - 0s 228us/sample - loss: 0.0088 - val_loss: 0.1897
# Epoch 415/600
# 398/398 [==============================] - 0s 203us/sample - loss: 0.0091 - val_loss: 0.1885
# Epoch 416/600
# 398/398 [==============================] - 0s 208us/sample - loss: 0.0106 - val_loss: 0.1890
# Epoch 417/600
# 398/398 [==============================] - 0s 203us/sample - loss: 0.0087 - val_loss: 0.1971
# Epoch 418/600
# 398/398 [==============================] - 0s 246us/sample - loss: 0.0095 - val_loss: 0.1977
# Epoch 419/600
# 398/398 [==============================] - 0s 195us/sample - loss: 0.0105 - val_loss: 0.1965
# Epoch 420/600
# 398/398 [==============================] - 0s 203us/sample - loss: 0.0086 - val_loss: 0.1904
# Epoch 421/600
# 398/398 [==============================] - 0s 200us/sample - loss: 0.0089 - val_loss: 0.1985
# Epoch 422/600
# 398/398 [==============================] - 0s 253us/sample - loss: 0.0096 - val_loss: 0.1995
# ...

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()

# %%
model = Sequential()
model.add(Dense(30,activation='relu'))

model.add(Dense(15,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer = "adam", loss = 'binary_crossentropy')

# %%
early_stop  = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=X_train, y=y_train.values,validation_data=(X_test,y_test.values),epochs=600, callbacks = [early_stop])
# Out:
# Train on 398 samples, validate on 171 samples
# Epoch 1/600
# 398/398 [==============================] - 1s 2ms/sample - loss: 0.6491 - val_loss: 0.6399
# Epoch 2/600
# 398/398 [==============================] - 0s 138us/sample - loss: 0.6036 - val_loss: 0.6020
# Epoch 3/600
# 398/398 [==============================] - 0s 135us/sample - loss: 0.5648 - val_loss: 0.5593
# Epoch 4/600
# 398/398 [==============================] - 0s 135us/sample - loss: 0.5186 - val_loss: 0.5135
# Epoch 5/600
# 398/398 [==============================] - 0s 145us/sample - loss: 0.4693 - val_loss: 0.4650
# Epoch 6/600
# 398/398 [==============================] - 0s 145us/sample - loss: 0.4191 - val_loss: 0.4177
# Epoch 7/600
# 398/398 [==============================] - 0s 153us/sample - loss: 0.3724 - val_loss: 0.3747
# Epoch 8/600
# 398/398 [==============================] - 0s 150us/sample - loss: 0.3291 - val_loss: 0.3338
# Epoch 9/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()

# %%
model = Sequential()
model.add(Dense(30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer = "adam", loss = 'binary_crossentropy')

# %%
model.fit(x=X_train, y=y_train.values,validation_data=(X_test,y_test.values),epochs=600, callbacks = [early_stop])
# Out:
# Train on 398 samples, validate on 171 samples
# Epoch 1/600
# 398/398 [==============================] - 1s 1ms/sample - loss: 0.6883 - val_loss: 0.6756
# Epoch 2/600
# 398/398 [==============================] - 0s 144us/sample - loss: 0.6826 - val_loss: 0.6621
# Epoch 3/600
# 398/398 [==============================] - 0s 150us/sample - loss: 0.6769 - val_loss: 0.6529
# Epoch 4/600
# 398/398 [==============================] - 0s 135us/sample - loss: 0.6688 - val_loss: 0.6421
# Epoch 5/600
# 398/398 [==============================] - 0s 138us/sample - loss: 0.6358 - val_loss: 0.6241
# Epoch 6/600
# 398/398 [==============================] - 0s 135us/sample - loss: 0.6348 - val_loss: 0.6059
# Epoch 7/600
# 398/398 [==============================] - 0s 135us/sample - loss: 0.6323 - val_loss: 0.5875
# Epoch 8/600
# 398/398 [==============================] - 0s 140us/sample - loss: 0.6003 - val_loss: 0.5651
# Epoch 9/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()

# %%
prediction = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,prediction))
# Out:
# precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        66
#            1       0.97      0.98      0.98       105
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[ 63   3]
#  [  2 103]]
